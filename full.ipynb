# %%
import pandas as pd

# %%
full_df = pd.read_csv("data/processed/full_df.csv")

# %%
full_df
# Out:
#         order_id         created_date  total_paid            state      sku  \
# 0         299539  2017-01-01 00:07:19       18.99  Shopping Basket  OTT0133
# 1         299540  2017-01-01 00:19:45      399.00  Shopping Basket  LGE0043
# 2         299541  2017-01-01 00:20:57      474.05  Shopping Basket  PAR0071
# 3         299542  2017-01-01 00:51:40       68.39  Shopping Basket  WDT0315
# 4         299543  2017-01-01 01:06:38       23.74  Shopping Basket  JBL0104
# ...          ...                  ...         ...              ...      ...
# 285434    527397  2018-03-14 13:56:38       42.99      Place Order  JBL0122
# 285435    527398  2018-03-14 13:57:25       42.99  Shopping Basket  JBL0122
# 285436    527399  2018-03-14 13:57:34      141.58  Shopping Basket  PAC0653
# 285437    527400  2018-03-14 13:57:41       19.98  Shopping Basket  APP0698
# 285438    527401  2018-03-14 13:58:36       18.98      Place Order  APP0927
#
# ...

# %%
# only orders with state Completed
completed_orders = full_df.loc[full_df["state"] == "Completed"]

# %%
completed_orders
# Out:
#         order_id         created_date  total_paid      state        sku  \
# 7         299545  2017-01-01 01:51:47       51.48  Completed    OWC0100
# 8         299546  2017-01-01 01:57:34       18.99  Completed    IOT0014
# 9         295347  2017-01-01 02:02:38       72.19  Completed    APP0700
# 11        299549  2017-01-02 10:00:20     2565.99  Completed    PAC0929
# 18        299556  2017-01-01 02:30:08       65.89  Completed  CRU0039-A
# ...          ...                  ...         ...        ...        ...
# 285059    525664  2018-03-14 11:56:19       85.73  Completed    TUC0207
# 285076    527070  2018-03-14 11:50:48       24.97  Completed    APP0698
# 285081    527074  2018-03-14 11:51:42       24.97  Completed    APP0698
# 285104    527096  2018-03-14 11:58:40       34.96  Completed    APP0698
# 285120    527112  2018-03-14 12:03:52       14.98  Completed    APP0698
#
#                                                      name  \
# ...

# %%
completed_orders[["state", "name"]].groupby("state").count()
# Out:
#             name
# state
# Completed  60219

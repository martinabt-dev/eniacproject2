# %%
import pandas as pd

# %%
products_df = pd.read_csv("data/raw/products.csv")

# %%
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# ...

# %%
products_df = products_df.drop_duplicates()

# %%
products_df[products_df["sku"].duplicated(keep=False)]
# Out:
#           sku                                               name  \
# 7992  APP1197  Apple iMac 21.5 "Core i5 31 GHz Retina display...
# 8000  APP1197  Apple iMac 21.5 "Core i5 31 GHz Retina display...
#
#                                                    desc price promo_price  \
# 7992  Desktop Apple iMac 21.5 inch i5 31 GHz Retina ...  1729     1305.59
# 8000  Desktop Apple iMac 21.5 inch i5 31 GHz Retina ...   NaN     1305.59
#
#       in_stock  type
# 7992         0  1282
# 8000         0  1282

# %%
products_df = products_df.drop(8000)

# %%
products_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10579 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10579 non-null  str
#  1   name         10579 non-null  str
#  2   desc         10572 non-null  str
#  3   price        10534 non-null  str
#  4   promo_price  10579 non-null  str
#  5   in_stock     10579 non-null  int64
#  6   type         10529 non-null  str
# dtypes: int64(1), str(6)
# memory usage: 661.2 KB

# %%
products_df["type"] = products_df["type"].str.replace(",", ".")

# %%
products_df["type"] = pd.to_numeric(products_df["type"])

# %%
products_df.loc[products_df["sku"] == "PAC2313"]
# Out:
#            sku                                               name  \
# 15922  PAC2313  Synology DS1517 + NAS Server | 8GB RAM | 60TB ...
#
#                                                   desc       price  \
# 15922  NAS server with 8GB RAM and 60TB for Mac and PC  34.187.885
#
#       promo_price  in_stock        type
# 15922   2.759.912         0  12175397.0

# %%
products_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 10579 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          10579 non-null  str
#  1   name         10579 non-null  str
#  2   desc         10572 non-null  str
#  3   price        10534 non-null  str
#  4   promo_price  10579 non-null  str
#  5   in_stock     10579 non-null  int64
#  6   type         10529 non-null  float64
# dtypes: float64(1), int64(1), str(5)
# memory usage: 661.2 KB

# %%
mask = products_df["price"].astype(str).str.contains(r"\d\d\.\d\d\d\.\d\d\d$", na=False)

products_df["price"] = products_df["price"].astype("object")

products_df.loc[mask, "price"] = (
    products_df.loc[mask, "price"]
    .astype(str)
    .str.replace(".", "", regex = False)
    .astype(float)
    / 10000
)

# %%
mask = products_df["price"].astype(str).str.contains(r"\.\d\d\d\.\d\d\d$", na=False)

products_df["price"] = products_df["price"].astype("object")

products_df.loc[mask, "price"] = (
    products_df.loc[mask, "price"]
    .astype(str)
    .str.replace(".", "", regex = False)
    .astype(float)
    / 100000
)

# %%
mask = products_df["price"].astype(str).str.contains(r"\d\d\d\.\d\d\d$", na=False)

products_df["price"] = products_df["price"].astype("object")

products_df.loc[mask, "price"] = (
    products_df.loc[mask, "price"]
    .astype(str)
    .str.replace(".", "", regex = False)
    .astype(float)
    / 10000
)

# %%
products_df["price"] = pd.to_numeric(products_df["price"])

# %%
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# ...

# %%
products_df = products_df.drop("promo_price", axis = 1)

# %%
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price  in_stock  \
# 0           Aluminum support compatible with all MacBook  59.99         1
# ...

# %%
products_df = products_df.dropna(subset = ["price"])

# %%
products_df.loc[products_df["desc"].isna()]
# Out:
#              sku                                               name desc  \
# 16126  WDT0211-A  Open - Purple 2TB WD 35 "PC Security Mac hard ...  NaN
# 16128  APP1622-A  Open - Apple Smart Keyboard Pro Keyboard Folio...  NaN
# 17843    PAC2334             Synology DS718 + NAS Server | 10GB RAM  NaN
# 18152  KAN0034-A  Open - Kanex USB-C Gigabit Ethernet Adapter Ma...  NaN
# 18490    HTE0025  Hyper Pearl 1600mAh battery Mini USB Mirror an...  NaN
# 18612    OTT0200    OtterBox External Battery Power Pack 20000 mAHr  NaN
# 18690  HOW0001-A  Open - Honeywell thermostat Lyric zonificador ...  NaN
#
#            price  in_stock        type
# 16126  107.00000         0      1298.0
# 16128   15.68206         0      1298.0
# 17843  566.35000         0  12175397.0
# 18152   29.99000         0      1298.0
# 18490   24.99000         1      1515.0
# 18612   79.99000         1      1515.0
# 18690  199.99000         0  11905404.0

# %%
products_df.loc[products_df["desc"].isna(), "desc"] = \
    products_df.loc[products_df["desc"].isna(), "name"]

# %%
products_df["price"] = products_df["price"].round(2)

# %%
products_df.to_csv("data/processed/products.csv", index = False)

# %%
products_df
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price  in_stock  \
# 0           Aluminum support compatible with all MacBook  59.99         1
# ...

# %%
products_df.sample(50)
# Out:
#              sku                                               name  \
# 11890    MAC0129  Macally UC3HUB4C USB Hub-C 4 USB 3.1 ports USB...
# 11055    PAC1387  Pack QNAP TS-251 + | 2GB RAM | Seagate 16TB Ir...
# 2823     MYK0022                      MyKronoz ZeCircle Black Clock
# 12175    APP1575  Apple MacBook Retina 12 "Core m3 11GHz | 8GB R...
# 12938    MOP0090  Mophie Juice Pack 2.420mAh + Wireless Charging...
# 13573    APP1736  42mm Apple Watch Series 2 Aluminum Case and Sp...
# 18348    LIF0129      LifeProof Fre Case iPhone Waterproof 8/7 Lila
# 18601  APP2150-A  Open - Apple iPad Pro 10.5 "Wi-Fi + Cellular 6...
# 2751     BEZ0193      Be.ez LArobe MacBook Graphite 12 "Gray / Blue
# 816      WDT0196    Western Digital My Book Thunderbolt Duo 6TB Mac
# 16814    APP2304  Apple MacBook Pro 13 "Core i7 Touch Bar 35GHz ...
# 16037    AP20100     Like new - Apple Smart Cover iPad Mini 4 Stone
# 19192    RIN0011       Spotlight Ring Black Wired Wired CCTV camera
# ...

# %%
products_df.loc[products_df["sku"] == "PAC2313"]
# Out:
#            sku                                               name  \
# 15922  PAC2313  Synology DS1517 + NAS Server | 8GB RAM | 60TB ...
#
#                                                   desc    price  in_stock  \
# 15922  NAS server with 8GB RAM and 60TB for Mac and PC  3418.79         0
#
#              type
# 15922  12175397.0

# %%
products_df.sample(100)
# Out:
#            sku                                               name  \
# 13637  ZAG0029  Zagg Invisible Shield Glass Screen Protector i...
# 12985  TPL0024        TP-Link TL-MR6400 Router 4G Wi-Fi N 300Mbps
# 12463  PAC1415  Synology DS716 + II Pack | 8GB RAM | WD 6TB Ne...
# 1093   GTE0035   G-Tech G-RAID Thunderbolt Studio 2 6TB RAID Disk
# 11071  PAC1631    Pack QNAP TS-251 + | 2GB RAM | Seagate NAS 16TB
# ...        ...                                                ...
# 16319  APP2267  Apple MacBook Pro 13 "Core i5 Touch Bar 31GHz ...
# 11717  STI0007  Stil Mind London FOG Case iPhone 6 / 6S Cobalt...
# 18982  NET0025  Arlo Netgear Netgear accessory rechargeable ba...
# 2071   QNA0081        QNAP TS-251 | 4GB RAM Mac and PC Server Nas
# 12169  APP1541          Apple Smart Cover iPad Mini 4 Albaricoque
#
#                                                     desc    price  in_stock  \
# 13637  Protector Ultra soft edges beveled tempered gl...    19.99         0
# ...
